# %% [markdown]
# ## CLUSTERING

# %%
import pandas as pd
cc_df=pd.read_csv("CC_GENERAL.csv",sep=",")

# %% [markdown]
# # DATA PREPROCESSING

# %%
cc_df.head(20)
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0   C10001    40.900749           0.818182      95.40              0.00
# 1   C10002  3202.467416           0.909091       0.00              0.00
# 2   C10003  2495.148862           1.000000     773.17            773.17
# 3   C10004  1666.670542           0.636364    1499.00           1499.00
# 4   C10005   817.714335           1.000000      16.00             16.00
# 5   C10006  1809.828751           1.000000    1333.28              0.00
# 6   C10007   627.260806           1.000000    7091.01           6402.63
# 7   C10008  1823.652743           1.000000     436.20              0.00
# 8   C10009  1014.926473           1.000000     861.49            661.49
# 9   C10010   152.225975           0.545455    1281.60           1281.60
# 10  C10011  1293.124939           1.000000     920.12              0.00
# 11  C10012   630.794744           0.818182    1492.18           1492.18
# ...

# %%
cc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
cc_df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
cc_df=cc_df.drop(["CUST_ID"],axis=1)

# %%
cc_df = cc_df.apply (pd.to_numeric, errors='coerce')
cc_df = cc_df.dropna()

print (cc_df)
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 4      817.714335           1.000000      16.00             16.00
# 5     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8943     5.871712           0.500000      20.90             20.90
# 8945    28.493517           1.000000     291.12              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cc_df["CREDIT_LIMIT"].value_counts()
# Out:
# 3000.000000     752
# 1500.000000     695
# 1200.000000     597
# 1000.000000     596
# 2500.000000     584
#                ...
# 8100.000000       1
# 12200.000000      1
# 11100.000000      1
# 13600.000000      1
# 1833.333333       1
# Name: CREDIT_LIMIT, Length: 203, dtype: int64

# %%
cc_df["MINIMUM_PAYMENTS"].value_counts()
# Out:
# 299.351881    2
# 342.286490    1
# 184.464721    1
# 276.486072    1
# 309.140865    1
#              ..
# 181.773223    1
# 711.894455    1
# 256.522546    1
# 127.799107    1
# 88.288956     1
# Name: MINIMUM_PAYMENTS, Length: 8635, dtype: int64

# %%
cc_df.isnull().sum().sum()
# Out:
# 0

# %%
#2.clustering model
from sklearn.cluster import AgglomerativeClustering #Importing our clustering algorithm : Agglomerative
model=AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='complete')
clust_labels=model.fit_predict(cc_df)  #Applying agglomerative algorithm with 5 clusters, using euclidean distance as a metric

# %%
from sklearn.cluster import KMeans
 
#Initialize the class object
kmeans = KMeans(n_clusters= 5)
 
#predict the labels of clusters.
label = kmeans.fit_predict(cc_df)
 
print(label)
# Out:
# [3 4 0 ... 3 3 3]

# %%
#agglomirative label
agglomerative=pd.DataFrame(label)
agglomerative
# Out:
#       0
# 0     3
# 1     4
# 2     0
# 3     3
# 4     3
# ...  ..
# 8631  3
# 8632  3
# 8633  3
# 8634  3
# 8635  3
#
# [8636 rows x 1 columns]

# %%
cc_df.corr()['BALANCE'].sort_values()
# Out:
# PRC_FULL_PAYMENT                   -0.333594
# PURCHASES_FREQUENCY                -0.088459
# PURCHASES_INSTALLMENTS_FREQUENCY   -0.069582
# ONEOFF_PURCHASES_FREQUENCY          0.063832
# TENURE                              0.066987
# INSTALLMENTS_PURCHASES              0.122109
# PURCHASES_TRX                       0.147887
# ONEOFF_PURCHASES                    0.159985
# PURCHASES                           0.176083
# BALANCE_FREQUENCY                   0.310140
# PAYMENTS                            0.322830
# CASH_ADVANCE_TRX                    0.382388
# MINIMUM_PAYMENTS                    0.398669
# CASH_ADVANCE_FREQUENCY              0.445307
# CASH_ADVANCE                        0.495586
# CREDIT_LIMIT                        0.535518
# BALANCE                             1.000000
# Name: BALANCE, dtype: float64

# %%
#3.agglomerative plot
import matplotlib.pyplot as plt
fig =plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter (cc_df ["BALANCE"] , cc_df ["CREDIT_LIMIT"] , c= agglomerative[0], s=50)
ax.set_title("Agglomerative Clutering")
ax.set_xlabel("BALANCE")
ax.set_ylabel("CREDIT_LIMIT")
plt.colorbar(scatter)

# %%
#4.dendograme plot
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title("Customer Dendrograms")
dend=shc.dendrogram(shc.linkage(cc_df, method="complete"))

# %%
#k-mean
from sklearn.cluster import KMeans  #Importing our clustering algorithm: KMeans
kmeans=KMeans(n_clusters=5, random_state=0)  #Cluster our data by choosing 5 as number of clusters
kmeans.fit(cc_df)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
#k-mean centroid
kmeans.predict(cc_df)
print(kmeans.cluster_centers_)   #Printing the coordinates of cluster centers.
# Out:
# [[1.66503019e+03 9.14361713e-01 1.47503260e+03 9.18786902e+02
#   5.56646307e+02 8.28890360e+02 5.85030946e-01 3.32812272e-01
#   4.06692380e-01 1.18189873e-01 2.76840364e+00 2.11641853e+01
#   6.85898940e+03 2.03803373e+03 6.51760367e+02 2.01143389e-01
#   1.17613730e+01]
#  [5.53273664e+03 9.61557868e-01 1.53395581e+03 9.31219725e+02
#   6.02812772e+02 3.87556288e+03 4.71996835e-01 2.62135945e-01
#   3.51735457e-01 3.31860533e-01 9.79839633e+00 2.14891180e+01
#   1.09134645e+04 4.08273785e+03 1.98483863e+03 6.94990561e-02
#   1.16712486e+01]
#  [4.81833846e+03 9.15015009e-01 1.18136954e+04 8.44763973e+03
#   3.36625387e+03 5.20289245e+03 7.72304108e-01 6.27834342e-01
#   6.15939333e-01 2.06865937e-01 8.84684685e+00 8.97837838e+01
#   1.26891892e+04 1.89200826e+04 2.45458930e+03 3.59580649e-01
#   1.18558559e+01]
#  [8.21415192e+02 8.73775090e-01 4.99297450e+02 2.39657323e+02
#   2.59953639e+02 4.97000151e+02 4.52674155e-01 1.29540009e-01
# ...

# %%
#k-mean plot
# agglomerative clustering
from numpy import unique
from numpy import where
from sklearn.cluster import AgglomerativeClustering
from matplotlib import pyplot
# define dataset
X, _ = make_classification(n_samples=len(cc_df), n_features=16, n_informative=5, n_redundant=0, n_clusters_per_class=1, random_state=4)
# define the model
model = AgglomerativeClustering(n_clusters=3)
# fit model and predict clusters
y = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(y == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
#k-mean plot
import matplotlib.pyplot as plt
plt.scatter(cc_df["BALANCE"][cc_df.agglomerative == 0],          
            cc_df["CREDIT_LIMIT"][cc_df.agglomerative == 0],s=80,c='magenta',label='Careful')
plt.scatter(cc_df["BALANCE"][cc_df.agglomerative == 1],
           cc_df["CREDIT_LIMIT)"][cc_df.agglomerative == 1],s=80,c='yellow',label='Standard')
plt.scatter(cc_df["BALANCE"][cc_df.agglomerative == 2],
           cc_df["CREDIT_LIMIT)"][cc_df.agglomerative == 2],s=80,c='green',label='Target')
plt.scatter(cc_df["BALANCE"][cc_df.agglomerative == 3], 
           cc_df["CREDIT_LIMIT"][cc_df.agglomerative == 3],s=80,c='cyan',label='Careless')
plt.scatter(cc_df["BALANCE"][cc_df.agglomerative == 4], 
           cc_df["CREDIT_LIMIT"][cc_df.agglomerative == 4],s=80,c='burlywood',label='Sensible')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label = 'Centroids')
plt.title('Clusters of Customers')
plt.xlabel('BALANCE)')
plt.ylabel('CREDIT_LIMIT')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14308/4113073889.py in <module>
#       1 #k-mean plot
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.scatter(cc_df["BALANCE"][cc_df.agglomerative == 0],
#       4             cc_df["CREDIT_LIMIT"][cc_df.agglomerative == 0],s=80,c='magenta',label='Careful')
#       5 plt.scatter(cc_df["BALANCE"][cc_df.agglomerative == 1],
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'agglomerative'

# %%
from matplotlib.pyplot import plot as plt
#Getting unique labels
 
u_labels = np.unique(label)
 
#plotting the results:
 
for i in u_labels:
    plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14308/3513383816.py in <module>
#       7
#       8 for i in u_labels:
# ----> 9     plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)
#      10 plt.legend()
#      11 plt.show()
#
# AttributeError: 'function' object has no attribute 'scatter'

# %%
#best k-value
from sklearn.cluster import KMeans
sum_of_squared_distances=[]
k=range(1,15)
for k in k:
    km=kMeans(n_clusters=k)
    km=km.fit(cc_df)
    sum_of_squared_distances.append(km.intertia_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14308/3659128103.py in <module>
#       4 k=range(1,15)
#       5 for k in k:
# ----> 6     km=kMeans(n_clusters=k)
#       7     km=km.fit(cc_df)
#       8     sum_of_squared_distances.append(km.intertia_)
#
# NameError: name 'kMeans' is not defined
